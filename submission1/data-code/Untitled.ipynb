# %% [markdown]
# # Medicare Advantage Data Analysis
# ## 1. Enrollment Data Analysis
# Shegofa Alizada
# Assignment2/Submission1

# %% [markdown]
# 1. Set the Working Directory

# %%
setwd("/home/salizad/econ470/a0/work/ma-data/ma/enrollment/Extracted Data/")

# %% [markdown]
# 2. Load Necessary Libraries

# %%
# Load necessary libraries
library(tidyr)
library(vroom)
library(dplyr)
library(ggplot2)
library(purrr)
#library(readr)  # For reading CSV files

# %% [markdown]
# 3. Define the Years & a Month List for Analysis

# %%
# Define the year for analysis
years <- 2014:2019  # Example year, change as needed

# Create a month list based on the year
monthlist <- sprintf("%02d", 1:12)

# %% [markdown]
# 4. Define Functions for Data Reading

# %% [markdown]
# 4.1 Reader for Contract Data

# %%
# Reader for contract data
read_contract <- function(path) {
  read_csv(
    path,
    skip = 1,
    col_names = c(
      "contractid", "planid", "org_type", "plan_type", "partd", "snp", "eghp",
      "org_name", "org_marketing_name", "plan_name", "parent_org", "contract_date"
    ),
    col_types = cols(
      contractid = col_character(),
      planid = col_double(),
      org_type = col_character(),
      plan_type = col_character(),
      partd = col_character(),
      snp = col_character(),
      eghp = col_character(),
      org_name = col_character(),
      org_marketing_name = col_character(),
      plan_name = col_character(),
      parent_org = col_character(),
      contract_date = col_character()
    ),
    show_col_types = FALSE,
    progress = FALSE
  )
}

# %% [markdown]
# 4.2 Reader for Enrollment Data

# %%
# Reader for enrollment data
read_enroll <- function(path) {
  read_csv(
    path,
    skip = 1,
    col_names = c("contractid", "planid", "ssa", "fips", "state", "county", "enrollment"),
    col_types = cols(
      contractid = col_character(),
      planid = col_double(),
      ssa = col_double(),
      fips = col_double(),
      state = col_character(),
      county = col_character(),
      enrollment = col_double()
    ),
    na = "*",
    show_col_types = FALSE,
    progress = FALSE
  )
}

# %% [markdown]
# 4.3 Load Monthly Data Function

# %%
load_month <- function(m, y) {
  c_path <- paste0("CPSC_Contract_Info_", y, "_", m, ".csv")
  e_path <- paste0("CPSC_Enrollment_Info_", y, "_", m, ".csv")

  # Print paths for debugging
  print(c_path)
  print(e_path)

  # Check if files exist
  if (!file.exists(c_path)) {
    warning(paste("Contract file does not exist:", c_path))
    return(data.frame())  # Return empty if contract file is not found
  }
  
  if (!file.exists(e_path)) {
    warning(paste("Enrollment file does not exist:", e_path))
    return(data.frame())  # Return empty if enrollment file is not found
  }

  # Use vroom to read the files and suppress column type messages
  contract.info <- vroom(c_path, show_col_types = FALSE) %>%
    distinct(`Contract ID`, `Plan ID`, .keep_all = TRUE)  # Use backticks for spaces

  enroll.info <- vroom(e_path, show_col_types = FALSE)  # Suppress column type messages

  if (nrow(enroll.info) == 0) {
    warning(paste("Enrollment file is empty:", e_path))
    return(data.frame())  # Return empty if enrollment is empty
  }

  if (nrow(contract.info) == 0) {
    warning(paste("Contract file is empty:", c_path))
    return(data.frame())  # Return empty if contract is empty
  }

  contract.info %>%
    left_join(enroll.info, by = c("Contract ID" = "Plan ID")) %>%  # Adjust join if names differ
    mutate(month = as.integer(m), year = y)
}
load_month("01", 2015)
# Out:
# [1] "CPSC_Contract_Info_2015_01.csv"
# [1] "CPSC_Enrollment_Info_2015_01.csv"
#      Contract ID Plan ID Organization Type
# 1    90091       NA      HCPP - 1833 Cost
# 2    E0654       801     Employer/Union Only Direct Contract PDP
# 3    E0654       802     Employer/Union Only Direct Contract PDP
# 4    E0654       803     Employer/Union Only Direct Contract PDP
# 5    E2630       801     Employer/Union Only Direct Contract PDP
# 6    E3014       801     Employer/Union Only Direct Contract PDP
# 7    E4744       801     Employer/Union Only Direct Contract PDP
# 8    E7316       801     Employer/Union Only Direct Contract PDP
# 9    E7848       801     Employer/Union Only Direct Contract PDP
# 10   H0022       001     Demo
# 11   H0028       001     Local CCP
# 12   H0028       002     Local CCP
# 13   H0028       003     Local CCP
# 14   H0028       004     Local CCP
# 15   H0028       801     Local CCP
# 16   H0028       802     Local CCP
# 17   H0084       001     Local CCP
# 18   H0084       004     Local CCP
# 19   H0084       014     Local CCP
# 20   H0104       010     Local CCP
# 21   H0104       011     Local CCP
# 22   H0104       801     Local CCP
# 23   H0104       802     Local CCP
# 24   H0104       804     Local CCP
# 25   H0105       001     National PACE
# 26   H0105       002     National PACE
# 27   H0107       001     Local CCP
# 28   H0107       002     Local CCP
# 29   H0107       801     Local CCP
# 30   H0107       802     Local CCP
# ⋮    ⋮           ⋮       ⋮
# 5044 S9579       046     Medicare Prescription Drug Plan
# 5045 S9579       047     Medicare Prescription Drug Plan
# 5046 S9579       048     Medicare Prescription Drug Plan
# 5047 S9579       049     Medicare Prescription Drug Plan
# 5048 S9579       050     Medicare Prescription Drug Plan
# 5049 S9579       051     Medicare Prescription Drug Plan
# 5050 S9579       052     Medicare Prescription Drug Plan
# 5051 S9579       053     Medicare Prescription Drug Plan
# 5052 S9579       054     Medicare Prescription Drug Plan
# 5053 S9579       055     Medicare Prescription Drug Plan
# 5054 S9579       056     Medicare Prescription Drug Plan
# 5055 S9579       057     Medicare Prescription Drug Plan
# 5056 S9579       058     Medicare Prescription Drug Plan
# 5057 S9579       059     Medicare Prescription Drug Plan
# 5058 S9579       060     Medicare Prescription Drug Plan
# 5059 S9579       061     Medicare Prescription Drug Plan
# 5060 S9579       062     Medicare Prescription Drug Plan
# 5061 S9579       063     Medicare Prescription Drug Plan
# 5062 S9579       064     Medicare Prescription Drug Plan
# 5063 S9579       065     Medicare Prescription Drug Plan
# 5064 S9579       066     Medicare Prescription Drug Plan
# 5065 S9579       803     Medicare Prescription Drug Plan
# 5066 S9579       804     Medicare Prescription Drug Plan
# 5067 S9579       805     Medicare Prescription Drug Plan
# 5068 S9701       801     Medicare Prescription Drug Plan
# 5069 S9701       802     Medicare Prescription Drug Plan
# 5070 S9701       803     Medicare Prescription Drug Plan
# 5071 S9701       804     Medicare Prescription Drug Plan
# 5072 S9701       805     Medicare Prescription Drug Plan
# 5073 S9701       806     Medicare Prescription Drug Plan
#      Plan Type                               Offers Part D SNP Plan EGHP
# 1    HCPP - 1833 Cost                        No            No       No
# 2    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 3    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 4    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 5    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 6    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 7    Employer/Union Only Direct Contract PDP Yes           No       Yes
# 8    Employer/Union Only Direct Contract PDP Yes           No       Yes
#
# 22   Blue Advantage Employer Group Plan 801 (PPO)
# 23   Blue Advantage Employer Group Plan 802 (PPO)
# 24   Blue Advantage Employer Group Plan 804 (PPO)
# 25   The Methodist Oaks d.b.a. The Oaks PACE (PACE)
# 26   The Methodist Oaks d.b.a. The Oaks PACE (PACE)
# 27   Blue Cross Medicare Advantage Choice Plus (PPO)
# 28   Blue Cross Medicare Advantage Choice Premier (PPO)
# 29   Blue Cross Medicare Advantage Employer Ideal (PPO)
# 30   Blue Cross Medicare Advantage Employer Expanded (PPO)
# ⋮    ⋮
# 5044 Transamerica MedicareRx Choice (PDP)
# 5045 Transamerica MedicareRx Choice (PDP)
# 5046 Transamerica MedicareRx Choice (PDP)
# 5047 Transamerica MedicareRx Choice (PDP)
# 5048 Transamerica MedicareRx Choice (PDP)
# 5049 Transamerica MedicareRx Choice (PDP)
# 5050 Transamerica MedicareRx Choice (PDP)
# 5051 Transamerica MedicareRx Choice (PDP)
# 5052 Transamerica MedicareRx Choice (PDP)
# 5053 Transamerica MedicareRx Choice (PDP)
# 5054 Transamerica MedicareRx Choice (PDP)
# 5055 Transamerica MedicareRx Choice (PDP)
# 5056 Transamerica MedicareRx Choice (PDP)
# 5057 Transamerica MedicareRx Choice (PDP)
# 5058 Transamerica MedicareRx Choice (PDP)
# 5059 Transamerica MedicareRx Choice (PDP)
# 5060 Transamerica MedicareRx Choice (PDP)
# 5061 Transamerica MedicareRx Choice (PDP)
# 5062 Transamerica MedicareRx Choice (PDP)
# 5063 Transamerica MedicareRx Choice (PDP)
# 5064 Transamerica MedicareRx Choice (PDP)
# 5065 Medicare GenerationRx (PDP)
# 5066 Medicare GenerationRx (PDP)
# 5067 Medicare GenerationRx (PDP)
# 5068 Navitus MedicareRx (PDP)
# 5069 Navitus MedicareRx (PDP)
# 5070 Navitus MedicareRx (PDP)
# 5071 Navitus MedicareRx (PDP)
# 5072 Navitus MedicareRx (PDP)
# 5073 Navitus MedicareRx (PDP)
#      Parent Organization                              Contract Effective Date
# 1    UMWA Health and Retirement Funds                 02/01/1974 0:00:00
# 2    IBT Voluntary Employee Benefits Trust            01/01/2007 0:00:00
# 3    IBT Voluntary Employee Benefits Trust            01/01/2007 0:00:00
# 4    IBT Voluntary Employee Benefits Trust            01/01/2007 0:00:00
# 5    C & O Employees' Hospital Association            01/01/2007 0:00:00
# 6    Commonwealth of PA Pub Schools Retirement System 01/01/2007 0:00:00
# 7    Missouri Highways and Transportation Commission  01/01/2007 0:00:00
# 8    Union Pacific Railroad Employes Health Systems   01/01/2007 0:00:00
# 9    State of Oklahoma                                01/01/2007 0:00:00
# 10   Centene Corporation                              05/01/2014 0:00:00
# 11   Humana Inc.                                      01/01/2013 0:00:00
# 12   Humana Inc.                                      01/01/2013 0:00:00
# 13   Humana Inc.                                      01/01/2013 0:00:00
# 14   Humana Inc.                                      01/01/2013 0:00:00
# 15   Humana Inc.                                      01/01/2013 0:00:00
# 16   Humana Inc.                                      01/01/2013 0:00:00
# 17   UnitedHealth Group, Inc.                         01/01/2009 0:00:00
# 18   UnitedHealth Group, Inc.                         01/01/2009 0:00:00
# 19   UnitedHealth Group, Inc.                         01/01/2009 0:00:00
# 20   BlueCross BlueShield of Alabama                  07/01/2005 0:00:00
# 21   BlueCross BlueShield of Alabama                  07/01/2005 0:00:00
# 22   BlueCross BlueShield of Alabama                  07/01/2005 0:00:00
# 23   BlueCross BlueShield of Alabama                  07/01/2005 0:00:00
# 24   BlueCross BlueShield of Alabama                  07/01/2005 0:00:00
# 25   The Methodist Oaks                               03/01/2008 0:00:00
# 26   The Methodist Oaks                               03/01/2008 0:00:00
# 27   Health Care Service Corporation                  01/01/2014 0:00:00
# 28   Health Care Service Corporation                  01/01/2014 0:00:00
# 29   Health Care Service Corporation                  01/01/2014 0:00:00
# 30   Health Care Service Corporation                  01/01/2014 0:00:00
# ⋮    ⋮                                                ⋮
# 5044 Aegon N.V.                                       01/01/2012 0:00:00
# 5045 Aegon N.V.                                       01/01/2012 0:00:00
# 5046 Aegon N.V.                                       01/01/2012 0:00:00
# 5047 Aegon N.V.                                       01/01/2012 0:00:00
# 5048 Aegon N.V.                                       01/01/2012 0:00:00
# 5049 Aegon N.V.                                       01/01/2012 0:00:00
# 5050 Aegon N.V.                                       01/01/2012 0:00:00
# 5051 Aegon N.V.                                       01/01/2012 0:00:00
# 5052 Aegon N.V.                                       01/01/2012 0:00:00
# 5053 Aegon N.V.                                       01/01/2012 0:00:00
# 5054 Aegon N.V.                                       01/01/2012 0:00:00
# 5055 Aegon N.V.                                       01/01/2012 0:00:00
# 5056 Aegon N.V.                                       01/01/2012 0:00:00
# 5057 Aegon N.V.                                       01/01/2012 0:00:00
# 5058 Aegon N.V.                                       01/01/2012 0:00:00
# 5059 Aegon N.V.                                       01/01/2012 0:00:00
# 5060 Aegon N.V.                                       01/01/2012 0:00:00
# 5061 Aegon N.V.                                       01/01/2012 0:00:00
# 5062 Aegon N.V.                                       01/01/2012 0:00:00
# 5063 Aegon N.V.                                       01/01/2012 0:00:00
# 5064 Aegon N.V.                                       01/01/2012 0:00:00
# 5065 Aegon N.V.                                       01/01/2012 0:00:00
# 5066 Aegon N.V.                                       01/01/2012 0:00:00
# 5067 Aegon N.V.                                       01/01/2012 0:00:00
# 5068 SSM Healthcare Corporation                       01/01/2015 0:00:00
# 5069 SSM Healthcare Corporation                       01/01/2015 0:00:00
# 5070 SSM Healthcare Corporation                       01/01/2015 0:00:00
# 5071 SSM Healthcare Corporation                       01/01/2015 0:00:00
# 5072 SSM Healthcare Corporation                       01/01/2015 0:00:00
# 5073 SSM Healthcare Corporation                       01/01/2015 0:00:00
#      Contract Number SSA State County Code FIPS State County Code State County
# 1    NA              NA                    NA                     NA    NA
# 2    NA              NA                    NA                     NA    NA
# 3    NA              NA                    NA                     NA    NA
# 4    NA              NA                    NA                     NA    NA
# 5    NA              NA                    NA                     NA    NA
# 6    NA              NA                    NA                     NA    NA
# 7    NA              NA                    NA                     NA    NA
# 8    NA              NA                    NA                     NA    NA
# 9    NA              NA                    NA                     NA    NA
# 10   NA              NA                    NA                     NA    NA
# 11   NA              NA                    NA                     NA    NA
# 12   NA              NA                    NA                     NA    NA
# 13   NA              NA                    NA                     NA    NA
# 14   NA              NA                    NA                     NA    NA
# 15   NA              NA                    NA                     NA    NA
# 16   NA              NA                    NA                     NA    NA
# 17   NA              NA                    NA                     NA    NA
# 18   NA              NA                    NA                     NA    NA
# 19   NA              NA                    NA                     NA    NA
# 20   NA              NA                    NA                     NA    NA
# 21   NA              NA                    NA                     NA    NA
# 22   NA              NA                    NA                     NA    NA
# 23   NA              NA                    NA                     NA    NA
# 24   NA              NA                    NA                     NA    NA
# 25   NA              NA                    NA                     NA    NA
# 26   NA              NA                    NA                     NA    NA
# 27   NA              NA                    NA                     NA    NA
# 28   NA              NA                    NA                     NA    NA
# 29   NA              NA                    NA                     NA    NA
# 30   NA              NA                    NA                     NA    NA
# ⋮    ⋮               ⋮                     ⋮                      ⋮     ⋮
# 5044 NA              NA                    NA                     NA    NA
# 5045 NA              NA                    NA                     NA    NA
# 5046 NA              NA                    NA                     NA    NA
# 5047 NA              NA                    NA                     NA    NA
# 5048 NA              NA                    NA                     NA    NA
# 5049 NA              NA                    NA                     NA    NA
# 5050 NA              NA                    NA                     NA    NA
# 5051 NA              NA                    NA                     NA    NA
# 5052 NA              NA                    NA                     NA    NA
# 5053 NA              NA                    NA                     NA    NA
# 5054 NA              NA                    NA                     NA    NA
# 5055 NA              NA                    NA                     NA    NA
# 5056 NA              NA                    NA                     NA    NA
# 5057 NA              NA                    NA                     NA    NA
# 5058 NA              NA                    NA                     NA    NA
# 5059 NA              NA                    NA                     NA    NA
# 5060 NA              NA                    NA                     NA    NA
# 5061 NA              NA                    NA                     NA    NA
# 5062 NA              NA                    NA                     NA    NA
# 5063 NA              NA                    NA                     NA    NA
# 5064 NA              NA                    NA                     NA    NA
# 5065 NA              NA                    NA                     NA    NA
# 5066 NA              NA                    NA                     NA    NA
# 5067 NA              NA                    NA                     NA    NA
# 5068 NA              NA                    NA                     NA    NA
# 5069 NA              NA                    NA                     NA    NA
# 5070 NA              NA                    NA                     NA    NA
# 5071 NA              NA                    NA                     NA    NA
# 5072 NA              NA                    NA                     NA    NA
# 5073 NA              NA                    NA                     NA    NA
#      Enrollment month year
# 1    NA         1     2015
# 2    NA         1     2015
# 3    NA         1     2015
# 4    NA         1     2015
# 5    NA         1     2015
# 6    NA         1     2015
# 7    NA         1     2015
# 8    NA         1     2015
# 9    NA         1     2015
# 10   NA         1     2015
# 11   NA         1     2015
# 12   NA         1     2015
# 13   NA         1     2015
# 14   NA         1     2015
# 15   NA         1     2015
# 16   NA         1     2015
# 17   NA         1     2015
# 18   NA         1     2015
# 19   NA         1     2015
# 20   NA         1     2015
# 21   NA         1     2015
# 22   NA         1     2015
# 23   NA         1     2015
# 24   NA         1     2015
# 25   NA         1     2015
# 26   NA         1     2015
# 27   NA         1     2015
# 28   NA         1     2015
# 29   NA         1     2015
# 30   NA         1     2015
# ⋮    ⋮          ⋮     ⋮
# 5044 NA         1     2015
# 5045 NA         1     2015
# 5046 NA         1     2015
# 5047 NA         1     2015
# 5048 NA         1     2015
# 5049 NA         1     2015
# 5050 NA         1     2015
# 5051 NA         1     2015
# 5052 NA         1     2015
# 5053 NA         1     2015
# 5054 NA         1     2015
# 5055 NA         1     2015
# 5056 NA         1     2015
# 5057 NA         1     2015
# 5058 NA         1     2015
# 5059 NA         1     2015
# 5060 NA         1     2015
# 5061 NA         1     2015
# 5062 NA         1     2015
# 5063 NA         1     2015
# 5064 NA         1     2015
# 5065 NA         1     2015
# 5066 NA         1     2015
# 5067 NA         1     2015
# 5068 NA         1     2015
# 5069 NA         1     2015
# 5070 NA         1     2015
# 5071 NA         1     2015
# 5072 NA         1     2015
# 5073 NA         1     2015

# %% [markdown]
# 5. Initialize List for Yearly Data

# %%
# Initialize an empty list to store yearly data
yearly_data_list <- list()

# %% [markdown]
# 6. Load and Collapse Data for Each Year

# %%
# Load and collapse data for each year
for (year in years) {
  # Load monthly data for the current year
  data <- map_dfr(monthlist, ~load_month(.x, year))
  
  # Filter out unwanted plans
  filtered_data <- data %>%
    filter(!`Plan Type` %in% c("SNP", "800-series", "Prescription Drug Only"))

  # Summarize Count distinct plans per county for the current year
  yearly_summary <- filtered_data %>%
    group_by(`State`, `County`) %>%
    summarize(plan_count = n_distinct(`Plan ID`), .groups = "drop") %>%
    mutate(year = year)  # Add year to the summary

  # Append the current year's summary to the list
  yearly_data_list[[as.character(year)]] <- yearly_summary
}
# Out:
# [1] "CPSC_Contract_Info_2014_01.csv"
# [1] "CPSC_Enrollment_Info_2014_01.csv"
# [1] "CPSC_Contract_Info_2014_02.csv"
# [1] "CPSC_Enrollment_Info_2014_02.csv"
# [1] "CPSC_Contract_Info_2014_03.csv"
# [1] "CPSC_Enrollment_Info_2014_03.csv"
# [1] "CPSC_Contract_Info_2014_04.csv"
# [1] "CPSC_Enrollment_Info_2014_04.csv"
# [1] "CPSC_Contract_Info_2014_05.csv"
# [1] "CPSC_Enrollment_Info_2014_05.csv"
# [1] "CPSC_Contract_Info_2014_06.csv"
# [1] "CPSC_Enrollment_Info_2014_06.csv"
# [1] "CPSC_Contract_Info_2014_07.csv"
# [1] "CPSC_Enrollment_Info_2014_07.csv"
# [1] "CPSC_Contract_Info_2014_08.csv"
# [1] "CPSC_Enrollment_Info_2014_08.csv"
# [1] "CPSC_Contract_Info_2014_09.csv"
# [1] "CPSC_Enrollment_Info_2014_09.csv"
# [1] "CPSC_Contract_Info_2014_10.csv"
# [1] "CPSC_Enrollment_Info_2014_10.csv"
# [1] "CPSC_Contract_Info_2014_11.csv"
# [1] "CPSC_Enrollment_Info_2014_11.csv"
# [1] "CPSC_Contract_Info_2014_12.csv"
# [1] "CPSC_Enrollment_Info_2014_12.csv"
# [1] "CPSC_Contract_Info_2015_01.csv"
# [1] "CPSC_Enrollment_Info_2015_01.csv"
# [1] "CPSC_Contract_Info_2015_02.csv"
# [1] "CPSC_Enrollment_Info_2015_02.csv"
# [1] "CPSC_Contract_Info_2015_03.csv"
# [1] "CPSC_Enrollment_Info_2015_03.csv"
# [1] "CPSC_Contract_Info_2015_04.csv"
# [1] "CPSC_Enrollment_Info_2015_04.csv"
# [1] "CPSC_Contract_Info_2015_05.csv"
# [1] "CPSC_Enrollment_Info_2015_05.csv"
# [1] "CPSC_Contract_Info_2015_06.csv"
# [1] "CPSC_Contract_Info_2017_12.csv"
# [1] "CPSC_Enrollment_Info_2017_12.csv"
# [1] "CPSC_Contract_Info_2018_01.csv"
# [1] "CPSC_Enrollment_Info_2018_01.csv"
# [1] "CPSC_Contract_Info_2018_02.csv"
# [1] "CPSC_Enrollment_Info_2018_02.csv"
# [1] "CPSC_Contract_Info_2018_03.csv"
# [1] "CPSC_Enrollment_Info_2018_03.csv"
# [1] "CPSC_Contract_Info_2018_04.csv"
# [1] "CPSC_Enrollment_Info_2018_04.csv"
# [1] "CPSC_Contract_Info_2018_05.csv"
# [1] "CPSC_Enrollment_Info_2018_05.csv"
# [1] "CPSC_Contract_Info_2018_06.csv"
# [1] "CPSC_Enrollment_Info_2018_06.csv"
# [1] "CPSC_Contract_Info_2018_07.csv"
# [1] "CPSC_Enrollment_Info_2018_07.csv"
# [1] "CPSC_Contract_Info_2018_08.csv"
# [1] "CPSC_Enrollment_Info_2018_08.csv"
# [1] "CPSC_Contract_Info_2018_09.csv"
# [1] "CPSC_Enrollment_Info_2018_09.csv"
# [1] "CPSC_Contract_Info_2018_10.csv"
# [1] "CPSC_Enrollment_Info_2018_10.csv"
# [1] "CPSC_Contract_Info_2018_11.csv"
# [1] "CPSC_Enrollment_Info_2018_11.csv"
# [1] "CPSC_Contract_Info_2018_12.csv"
# [1] "CPSC_Enrollment_Info_2018_12.csv"
# [1] "CPSC_Contract_Info_2019_01.csv"
# [1] "CPSC_Enrollment_Info_2019_01.csv"
# [1] "CPSC_Contract_Info_2019_02.csv"
# [1] "CPSC_Enrollment_Info_2019_02.csv"
# [1] "CPSC_Contract_Info_2019_03.csv"
# [1] "CPSC_Enrollment_Info_2019_03.csv"
# [1] "CPSC_Contract_Info_2019_04.csv"
# [1] "CPSC_Enrollment_Info_2019_04.csv"
# [1] "CPSC_Contract_Info_2019_05.csv"
# [1] "CPSC_Enrollment_Info_2019_05.csv"
# [1] "CPSC_Contract_Info_2019_06.csv"
# [1] "CPSC_Enrollment_Info_2019_06.csv"
# [1] "CPSC_Contract_Info_2019_07.csv"
# [1] "CPSC_Enrollment_Info_2019_07.csv"
# [1] "CPSC_Contract_Info_2019_08.csv"
# [1] "CPSC_Enrollment_Info_2019_08.csv"
# [1] "CPSC_Contract_Info_2019_09.csv"
# [1] "CPSC_Enrollment_Info_2019_09.csv"
# [1] "CPSC_Contract_Info_2019_10.csv"
# [1] "CPSC_Enrollment_Info_2019_10.csv"
# [1] "CPSC_Contract_Info_2019_11.csv"
# [1] "CPSC_Enrollment_Info_2019_11.csv"
# [1] "CPSC_Contract_Info_2019_12.csv"
# [1] "CPSC_Enrollment_Info_2019_12.csv"

# %% [markdown]
# 7. Combine All Yearly Summaries into a Single Dataframe

# %%
# Combine all yearly summaries into a single dataframe
final_summary <- bind_rows(yearly_data_list)

# %% [markdown]
# 8. Create a Boxplot of Plan Counts by County Over the Years

# %%
# Create a boxplot of plan counts by county over the years
enrollment_plot <- ggplot(final_summary, aes(x = factor(year), y = plan_count)) +
  geom_boxplot() +
  labs(title = "Distribution of Plan Counts by County (2014-2019)",
       x = "Year", y = "Number of Plans")

# %% [markdown]
# 9. Specify the Output Directory for Visualizations

# %%
# Specify the output directory for visualizations
output_analysis_dir <- "/home/salizad/econ470/a0/work/Homework2/submission1/analysis"

# Create the directory structure if it doesn't exist
dir.create(output_analysis_dir, recursive = TRUE, showWarnings = FALSE)

# %% [markdown]
# 10. Output Results to the Console and Save Files

# %%
# Output results to the console
if (nrow(final_summary) == 0) {
  cat("No data loaded.\n")
} else {
  cat("Data loaded successfully:\n")
  print(head(final_summary))  # Show the first few rows
  
  # Save the summary to a CSV file
  write.csv(final_summary, file.path(output_analysis_dir, "enrollment_data_summary.csv"), row.names = FALSE)
  cat("Summary saved to 'enrollment_data_summary.csv'.\n")
  
  # Save the plot to the specified analysis directory
  ggsave(filename = file.path(output_analysis_dir, "enrollment_boxplot.png"), plot = enrollment_plot)
  cat("Boxplot saved to 'enrollment_boxplot.png'.\n")
}
# Out:
# Data loaded successfully:
# # A tibble: 6 × 4
#   State County plan_count  year
#   <chr> <chr>       <int> <int>
# 1 NA    NA            373  2014
# 2 NA    NA            360  2015
# 3 NA    NA            354  2016
# 4 NA    NA            353  2017
# 5 NA    NA            400  2018
# 6 NA    NA            428  2019
# Summary saved to 'enrollment_data_summary.csv'.
# Saving 6.67 x 6.67 in image
# Boxplot saved to 'enrollment_boxplot.png'.

# %% [markdown]
# ## 2. Analyzing Plan Bids in 2014 and 2018

# %% [markdown]
# 1. Loading LAndscape Data

# %% [markdown]
# 1.2 Loading necessary libraries

# %%
library(readr)
library(readxl)
library(stringr)

# %% [markdown]
# 1.1 Loading MA Landscape Data for 2014

# %%
setwd("/home/salizad/econ470/a0/work/ma-data/ma/landscape/Extracted Data/")

# %%
ma.path.2014 <- "/home/salizad/econ470/a0/work/ma-data/ma/landscape/Extracted Data/2014LandscapeSource file MA_AtoM 05292014.csv"
ma.data.2014 <- read_csv(ma.path.2014,
                          skip=6,
                          col_names=c("state","county","org_name","plan_name","plan_type","premium","partd_deductible",
                                      "drug_type","gap_coverage","drug_type_detail","contractid",
                                      "planid","segmentid","moop","star_rating"),
                          col_types = cols(
                            state = col_character(),
                            county = col_character(),
                            org_name = col_character(),
                            plan_name = col_character(),
                            plan_type = col_character(),
                            premium = col_character(),
                            partd_deductible = col_character(),
                            drug_type = col_character(),
                            gap_coverage = col_character(),
                            drug_type_detail = col_character(),
                            contractid = col_character(),
                            planid = col_double(),
                            segmentid = col_double(),
                            moop = col_character(),
                            star_rating = col_character()
                          )) %>%
  mutate_at(c('premium','partd_deductible'), ~str_replace(.,"-","0")) %>%
  mutate_at(c('premium','partd_deductible'), ~parse_number(.))

# %% [markdown]
# 1.2 Loading MA Landscape Data for 2018

# %%
ma.path.2018.a <- "/home/salizad/econ470/a0/work/ma-data/ma/landscape/Extracted Data/2018LandscapeSource file MA_AtoM 10142017.csv"

ma.data.2018.a <- read_csv(ma.path.2018.a,
                            skip = 6,
                            col_names = c("state", "county", "org_name", "plan_name", "plan_type", 
                                           "premium", "partd_deductible", "drug_type", "gap_coverage", 
                                           "drug_type_detail", "contractid", "planid", "segmentid", 
                                           "moop", "star_rating"),
                            col_types = cols(
                              state = col_character(),
                              county = col_character(),
                              org_name = col_character(),
                              plan_name = col_character(),
                              plan_type = col_character(),
                              premium = col_character(),
                              partd_deductible = col_character(),
                              drug_type = col_character(),
                              gap_coverage = col_character(),
                              drug_type_detail = col_character(),
                              contractid = col_character(),
                              planid = col_double(),
                              segmentid = col_double(),
                              moop = col_character(),
                              star_rating = col_character()
                            )) %>%
  mutate(across(c('premium', 'partd_deductible'), ~str_replace(., "-", "0"))) %>%
  mutate(across(c('premium', 'partd_deductible'), ~parse_number(.)))

# %% [markdown]
# 2. Loading Risk/Rebate Data

# %% [markdown]
# 2.1 Load Part C and Part D Risk/Rebate Data for 2014

# %%
# Load Part C Risk/Rebate Data for 2014
risk.rebate.path.2014 <- "/home/salizad/econ470/a0/work/ma-data/ma/cms-payment/2014/2014PartCPlan Level.xlsx"
risk.rebate.2014 <- read_xlsx(risk.rebate.path.2014, range="A4:G3620", sheet="result.srx",  # Use the correct sheet name
                               col_names=c("contractid","planid","contract_name","plan_type",
                                           "riskscore_partc","payment_partc","rebate_partc"))

# Load Part D Risk/Rebate Data for 2014
risk.rebate.path.2014D <- "/home/salizad/econ470/a0/work/ma-data/ma/cms-payment/2014/2014PartDPlans.xlsx"
risk.rebate.2014D <- read_xlsx(risk.rebate.path.2014D, range="A4:H4460", sheet="Sheet2",  # Use the correct sheet name
                               col_names=c("contractid","planid","contract_name","plan_type",
                                           "directsubsidy_partd","riskscore_partd","reinsurance_partd",
                                           "costsharing_partd"))

# %%
# Inspect the data frame
print(head(risk.rebate.2014D))  # View the first few rows
print(colnames(risk.rebate.2014D))  # Print column names
# Out:
# # A tibble: 0 × 0
# character(0)

# %% [markdown]
# 2.2 Load Part C and Part D Risk/Rebate Data for 2018

# %%
# Load Part C Risk/Rebate Data for 2018
risk.rebate.path.2018 <- "/home/salizad/econ470/a0/work/ma-data/ma/cms-payment/2018/2018PartCPlanLevel.xlsx"
risk.rebate.2018 <- read_xlsx(risk.rebate.path.2018, range="A4:G3620", sheet="result.srx",
                               col_names=c("contractid","planid","contract_name","plan_type",
                                           "riskscore_partc","payment_partc","rebate_partc"))

# Load Part D Risk/Rebate Data for 2018
risk.rebate.path.2018D <- "/home/salizad/econ470/a0/work/ma-data/ma/cms-payment/2018/2018PartDPlans.xlsx"
risk.rebate.2018D <- read_xlsx(risk.rebate.path.2018D, range="A4:H4460", sheet="result.srx",
                               col_names=c("contractid","planid","contract_name","plan_type",
                                           "directsubsidy_partd","riskscore_partd","reinsurance_partd",
                                           "costsharing_partd"))

# %% [markdown]
# 3. Cleaning and Preparing Risk/Rebate Data

# %% [markdown]
# 3.1 Cleaning Part C and D Data for 2014

# %%
# Clean Part C Data for 2014
risk.rebate.2014 <- risk.rebate.2014 %>%
  mutate(
    across(c(riskscore_partc, payment_partc, rebate_partc),
           ~ parse_number(as.character(.))),
    planid = as.numeric(planid),
    year   = 2014
  ) %>%
  select(contractid, planid, contract_name, plan_type,
         riskscore_partc, payment_partc, rebate_partc, year)

# Clean Part D Data for 2014
risk.rebate.2014D <- risk.rebate.2014D %>%
  mutate(
    across(c(directsubsidy_partd, reinsurance_partd, costsharing_partd),
           ~ parse_number(as.character(.))),
    payment_partd = directsubsidy_partd + reinsurance_partd + costsharing_partd,
    planid        = as.numeric(planid)
  ) %>%
  select(contractid, planid, payment_partd,
         directsubsidy_partd, reinsurance_partd, costsharing_partd,
         riskscore_partd)
# Out:
# Error in `mutate()`:
# ℹ In argument: `across(...)`.
# Caused by error in `across()`:
# ! Can't subset columns that don't exist.
# ✖ Column `directsubsidy_partd` doesn't exist.
# Traceback:
#
# 1. risk.rebate.2014D %>% mutate(across(c(directsubsidy_partd, reinsurance_partd,
#  .     costsharing_partd), ~parse_number(as.character(.))), payment_partd = directsubsidy_partd +
#  .     reinsurance_partd + costsharing_partd, planid = as.numeric(planid)) %>%
#  .     select(contractid, planid, payment_partd, directsubsidy_partd,
#  .         reinsurance_partd, costsharing_partd, riskscore_partd)
# 2. select(., contractid, planid, payment_partd, directsubsidy_partd,
#  .     reinsurance_partd, costsharing_partd, riskscore_partd)
# 3. mutate(., across(c(directsubsidy_partd, reinsurance_partd, costsharing_partd),
#  .     ~parse_number(as.character(.))), payment_partd = directsubsidy_partd +
#  .     reinsurance_partd + costsharing_partd, planid = as.numeric(planid))
# 4. mutate.data.frame(., across(c(directsubsidy_partd, reinsurance_partd,
#  .     costsharing_partd), ~parse_number(as.character(.))), payment_partd = directsubsidy_partd +
#  .     reinsurance_partd + costsharing_partd, planid = as.numeric(planid))
# 5. mutate_cols(.data, dplyr_quosures(...), by)
# 6. withCallingHandlers(for (i in seq_along(dots)) {
#  .     poke_error_context(dots, i, mask = mask)
#  .     context_poke("column", old_current_column)
#  .     new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#  . }, error = dplyr_error_handler(dots = dots, mask = mask, bullets = mutate_bullets,
#  .     error_call = error_call, error_class = "dplyr:::mutate_error"),
#  .     warning = dplyr_warning_handler(state = warnings_state, mask = mask,
#  .         error_call = error_call))
# 7. mutate_col(dots[[i]], data, mask, new_columns)
# 8. expand_across(dot)
# 9. across_setup(!!cols, fns = fns, names = eval_tidy(expr$.names,
#  .     mask, env = env), .caller_env = env, mask = dplyr_mask, error_call = error_call,
#  .     across_if_fn = across_if_fn)
# 10. tidyselect::eval_select(cols, data = data, error_call = error_call)
# 11. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#   .     exclude = exclude, strict = strict, name_spec = name_spec,
#   .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .     error_call = error_call, )
# 12. with_subscript_errors(out <- vars_select_eval(vars, expr, strict = strict,
#   .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#   .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .     type = type, error_call = error_call), type = type)
# 13. try_fetch(expr, vctrs_error_subscript = function(cnd) {
#   .     cnd$subscript_action <- subscript_action(type)
#   .     cnd$subscript_elt <- "column"
#   .     cnd_signal(cnd)
#   . })
# 14. withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "vctrs_error_subscript")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })
# 15. vars_select_eval(vars, expr, strict = strict, data = x, name_spec = name_spec,
#   .     uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .     allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .     type = type, error_call = error_call)
# 16. walk_data_tree(expr, data_mask, context_mask)
# 17. eval_c(expr, data_mask, context_mask)
# 18. reduce_sels(node, data_mask, context_mask, init = init)
# 19. walk_data_tree(new, data_mask, context_mask)
# 20. as_indices_sel_impl(out, vars = vars, strict = strict, data = data,
#   .     allow_predicates = allow_predicates, call = error_call, arg = as_label(expr))
# 21. as_indices_impl(x, vars, call = call, arg = arg, strict = strict)
# 22. chr_as_locations(x, vars, call = call, arg = arg)
# 23. vctrs::vec_as_location(x, n = length(vars), names = vars, call = call,
#   .     arg = arg)
# 24. (function ()
#   . stop_subscript_oob(i = i, subscript_type = subscript_type, names = names,
#   .     subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .     call = call))()
# 25. stop_subscript_oob(i = i, subscript_type = subscript_type, names = names,
#   .     subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .     call = call)
# 26. stop_subscript(class = "vctrs_error_subscript_oob", i = i, subscript_type = subscript_type,
#   .     ..., call = call)
# 27. abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .     call = call)
# 28. signal_abort(cnd, .file)
# 29. signalCondition(cnd)
# 30. (function (cnd)
#   . {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "vctrs_error_subscript")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .         debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .             2L, keep_warning = keep_warning, keep_message = keep_message,
#   .         log_echo = log_echo, log_warning = log_warning, output_handler = output_handler,
#   .         include_timing = include_timing), timing_fn(handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), try(f, silent = TRUE), tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call, nlines = 1L)
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), tryCatchList(expr, classes, parentenv, handlers),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler), withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers), eval(expr, envir, enclos),
#   .     eval(expr, envir, enclos), risk.rebate.2014D %>% mutate(across(c(directsubsidy_partd,
#   .         reinsurance_partd, costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)) %>%
#   .         select(contractid, planid, payment_partd, directsubsidy_partd,
#   .             reinsurance_partd, costsharing_partd, riskscore_partd),
#   .     select(., contractid, planid, payment_partd, directsubsidy_partd,
#   .         reinsurance_partd, costsharing_partd, riskscore_partd),
#   .     mutate(., across(c(directsubsidy_partd, reinsurance_partd,
#   .         costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)),
#   .     mutate.data.frame(., across(c(directsubsidy_partd, reinsurance_partd,
#   .         costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)),
#   .     mutate_cols(.data, dplyr_quosures(...), by), withCallingHandlers(for (i in seq_along(dots)) {
#   .         poke_error_context(dots, i, mask = mask)
#   .         context_poke("column", old_current_column)
#   .         new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#   .     }, error = dplyr_error_handler(dots = dots, mask = mask,
#   .         bullets = mutate_bullets, error_call = error_call, error_class = "dplyr:::mutate_error"),
#   .         warning = dplyr_warning_handler(state = warnings_state,
#   .             mask = mask, error_call = error_call)), mutate_col(dots[[i]],
#   .         data, mask, new_columns), expand_across(dot), across_setup(!!cols,
#   .         fns = fns, names = eval_tidy(expr$.names, mask, env = env),
#   .         .caller_env = env, mask = dplyr_mask, error_call = error_call,
#   .         across_if_fn = across_if_fn), tidyselect::eval_select(cols,
#   .         data = data, error_call = error_call), eval_select_impl(data,
#   .         names(data), as_quosure(expr, env), include = include,
#   .         exclude = exclude, strict = strict, name_spec = name_spec,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, error_call = error_call,
#   .         ), with_subscript_errors(out <- vars_select_eval(vars,
#   .         expr, strict = strict, data = x, name_spec = name_spec,
#   .         uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .         allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .         type = type, error_call = error_call), type = type),
#   .     try_fetch(expr, vctrs_error_subscript = function(cnd) {
#   .         cnd$subscript_action <- subscript_action(type)
#   .         cnd$subscript_elt <- "column"
#   .         cnd_signal(cnd)
#   .     }), withCallingHandlers(expr, condition = function(cnd) {
#   .         {
#   .             .__handler_frame__. <- TRUE
#   .             .__setup_frame__. <- frame
#   .             if (inherits(cnd, "message")) {
#   .                 except <- c("warning", "error")
#   .             }
#   .             else if (inherits(cnd, "warning")) {
#   .                 except <- "error"
#   .             }
#   .             else {
#   .                 except <- ""
#   .             }
#   .         }
#   .         while (!is_null(cnd)) {
#   .             if (inherits(cnd, "vctrs_error_subscript")) {
#   .                 out <- handlers[[1L]](cnd)
#   .                 if (!inherits(out, "rlang_zap"))
#   .                   throw(out)
#   .             }
#   .             inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .             if (is_false(inherit)) {
#   .                 return()
#   .             }
#   .             cnd <- .subset2(cnd, "parent")
#   .         }
#   .     }), vars_select_eval(vars, expr, strict = strict, data = x,
#   .         name_spec = name_spec, uniquely_named = uniquely_named,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, type = type, error_call = error_call),
#   .     walk_data_tree(expr, data_mask, context_mask), eval_c(expr,
#   .         data_mask, context_mask), reduce_sels(node, data_mask,
#   .         context_mask, init = init), walk_data_tree(new, data_mask,
#   .         context_mask), as_indices_sel_impl(out, vars = vars,
#   .         strict = strict, data = data, allow_predicates = allow_predicates,
#   .         call = error_call, arg = as_label(expr)), as_indices_impl(x,
#   .         vars, call = call, arg = arg, strict = strict), chr_as_locations(x,
#   .         vars, call = call, arg = arg), vctrs::vec_as_location(x,
#   .         n = length(vars), names = vars, call = call, arg = arg),
#   .     `<fn>`(), stop_subscript_oob(i = i, subscript_type = subscript_type,
#   .         names = names, subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .         call = call), stop_subscript(class = "vctrs_error_subscript_oob",
#   .         i = i, subscript_type = subscript_type, ..., call = call),
#   .     abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .         call = call)), parent = c(0L, 1L, 2L, 3L, 4L, 5L, 6L,
#   . 7L, 6L, 9L, 10L, 4L, 12L, 13L, 13L, 15L, 16L, 17L, 18L, 19L,
#   . 13L, 13L, 13L, 23L, 24L, 0L, 0L, 0L, 0L, 29L, 30L, 30L, 32L,
#   . 33L, 34L, 35L, 36L, 37L, 38L, 36L, 40L, 41L, 42L, 43L, 44L, 45L,
#   . 46L, 47L, 0L, 49L, 50L, 51L), visible = c(TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE), namespace = c("IRkernel",
#   . NA, "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "evaluate", "evaluate", "evaluate", "base",
#   . "base", "base", "base", "base", "base", "base", "evaluate", "base",
#   . "base", NA, "dplyr", "dplyr", "dplyr", "dplyr", "base", "dplyr",
#   . "dplyr", "dplyr", "tidyselect", "tidyselect", "tidyselect", "rlang",
#   . "base", "tidyselect", "tidyselect", "tidyselect", "tidyselect",
#   . "tidyselect", "tidyselect", "tidyselect", "tidyselect", "vctrs",
#   . "vctrs", "vctrs", "vctrs", "rlang"), scope = c("::", NA, "local",
#   . NA, "::", "local", "local", "local", "local", "local", "local",
#   . "::", ":::", "local", "local", "::", "::", "local", "local",
#   . "local", "::", "::", ":::", "::", "::", NA, "::", "::", ":::",
#   . ":::", "::", ":::", ":::", ":::", "::", ":::", ":::", "::", "::",
#   . ":::", ":::", ":::", ":::", ":::", ":::", ":::", ":::", "::",
#   . "local", ":::", ":::", "::"), error_frame = c(FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, TRUE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE)), row.names = c(NA, -52L), version = 2L, class = c("rlang_trace",
#   . "rlib_trace", "tbl", "data.frame")), parent = NULL, i = "directsubsidy_partd",
#   .     subscript_type = "character", names = character(0), subscript_action = NULL,
#   .     subscript_arg = "directsubsidy_partd", rlang = list(inherit = TRUE),
#   .     call = across()), class = c("vctrs_error_subscript_oob",
#   . "vctrs_error_subscript", "rlang_error", "error", "condition")))
# 31. handlers[[1L]](cnd)
# 32. cnd_signal(cnd)
# 33. signal_abort(cnd)
# 34. signalCondition(cnd)
# 35. (function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .         debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .             2L, keep_warning = keep_warning, keep_message = keep_message,
#   .         log_echo = log_echo, log_warning = log_warning, output_handler = output_handler,
#   .         include_timing = include_timing), timing_fn(handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), try(f, silent = TRUE), tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call, nlines = 1L)
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), tryCatchList(expr, classes, parentenv, handlers),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler), withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers), eval(expr, envir, enclos),
#   .     eval(expr, envir, enclos), risk.rebate.2014D %>% mutate(across(c(directsubsidy_partd,
#   .         reinsurance_partd, costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)) %>%
#   .         select(contractid, planid, payment_partd, directsubsidy_partd,
#   .             reinsurance_partd, costsharing_partd, riskscore_partd),
#   .     select(., contractid, planid, payment_partd, directsubsidy_partd,
#   .         reinsurance_partd, costsharing_partd, riskscore_partd),
#   .     mutate(., across(c(directsubsidy_partd, reinsurance_partd,
#   .         costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)),
#   .     mutate.data.frame(., across(c(directsubsidy_partd, reinsurance_partd,
#   .         costsharing_partd), ~parse_number(as.character(.))),
#   .         payment_partd = directsubsidy_partd + reinsurance_partd +
#   .             costsharing_partd, planid = as.numeric(planid)),
#   .     mutate_cols(.data, dplyr_quosures(...), by), withCallingHandlers(for (i in seq_along(dots)) {
#   .         poke_error_context(dots, i, mask = mask)
#   .         context_poke("column", old_current_column)
#   .         new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#   .     }, error = dplyr_error_handler(dots = dots, mask = mask,
#   .         bullets = mutate_bullets, error_call = error_call, error_class = "dplyr:::mutate_error"),
#   .         warning = dplyr_warning_handler(state = warnings_state,
#   .             mask = mask, error_call = error_call)), mutate_col(dots[[i]],
#   .         data, mask, new_columns), expand_across(dot), across_setup(!!cols,
#   .         fns = fns, names = eval_tidy(expr$.names, mask, env = env),
#   .         .caller_env = env, mask = dplyr_mask, error_call = error_call,
#   .         across_if_fn = across_if_fn), tidyselect::eval_select(cols,
#   .         data = data, error_call = error_call), eval_select_impl(data,
#   .         names(data), as_quosure(expr, env), include = include,
#   .         exclude = exclude, strict = strict, name_spec = name_spec,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, error_call = error_call,
#   .         ), with_subscript_errors(out <- vars_select_eval(vars,
#   .         expr, strict = strict, data = x, name_spec = name_spec,
#   .         uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .         allow_empty = allow_empty, allow_predicates = allow_predicates,
#   .         type = type, error_call = error_call), type = type),
#   .     try_fetch(expr, vctrs_error_subscript = function(cnd) {
#   .         cnd$subscript_action <- subscript_action(type)
#   .         cnd$subscript_elt <- "column"
#   .         cnd_signal(cnd)
#   .     }), withCallingHandlers(expr, condition = function(cnd) {
#   .         {
#   .             .__handler_frame__. <- TRUE
#   .             .__setup_frame__. <- frame
#   .             if (inherits(cnd, "message")) {
#   .                 except <- c("warning", "error")
#   .             }
#   .             else if (inherits(cnd, "warning")) {
#   .                 except <- "error"
#   .             }
#   .             else {
#   .                 except <- ""
#   .             }
#   .         }
#   .         while (!is_null(cnd)) {
#   .             if (inherits(cnd, "vctrs_error_subscript")) {
#   .                 out <- handlers[[1L]](cnd)
#   .                 if (!inherits(out, "rlang_zap"))
#   .                   throw(out)
#   .             }
#   .             inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .             if (is_false(inherit)) {
#   .                 return()
#   .             }
#   .             cnd <- .subset2(cnd, "parent")
#   .         }
#   .     }), vars_select_eval(vars, expr, strict = strict, data = x,
#   .         name_spec = name_spec, uniquely_named = uniquely_named,
#   .         allow_rename = allow_rename, allow_empty = allow_empty,
#   .         allow_predicates = allow_predicates, type = type, error_call = error_call),
#   .     walk_data_tree(expr, data_mask, context_mask), eval_c(expr,
#   .         data_mask, context_mask), reduce_sels(node, data_mask,
#   .         context_mask, init = init), walk_data_tree(new, data_mask,
#   .         context_mask), as_indices_sel_impl(out, vars = vars,
#   .         strict = strict, data = data, allow_predicates = allow_predicates,
#   .         call = error_call, arg = as_label(expr)), as_indices_impl(x,
#   .         vars, call = call, arg = arg, strict = strict), chr_as_locations(x,
#   .         vars, call = call, arg = arg), vctrs::vec_as_location(x,
#   .         n = length(vars), names = vars, call = call, arg = arg),
#   .     `<fn>`(), stop_subscript_oob(i = i, subscript_type = subscript_type,
#   .         names = names, subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .         call = call), stop_subscript(class = "vctrs_error_subscript_oob",
#   .         i = i, subscript_type = subscript_type, ..., call = call),
#   .     abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .         call = call)), parent = c(0L, 1L, 2L, 3L, 4L, 5L, 6L,
#   . 7L, 6L, 9L, 10L, 4L, 12L, 13L, 13L, 15L, 16L, 17L, 18L, 19L,
#   . 13L, 13L, 13L, 23L, 24L, 0L, 0L, 0L, 0L, 29L, 30L, 30L, 32L,
#   . 33L, 34L, 35L, 36L, 37L, 38L, 36L, 40L, 41L, 42L, 43L, 44L, 45L,
#   . 46L, 47L, 0L, 49L, 50L, 51L), visible = c(TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE), namespace = c("IRkernel",
#   . NA, "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "evaluate", "evaluate", "evaluate", "base",
#   . "base", "base", "base", "base", "base", "base", "evaluate", "base",
#   . "base", NA, "dplyr", "dplyr", "dplyr", "dplyr", "base", "dplyr",
#   . "dplyr", "dplyr", "tidyselect", "tidyselect", "tidyselect", "rlang",
#   . "base", "tidyselect", "tidyselect", "tidyselect", "tidyselect",
#   . "tidyselect", "tidyselect", "tidyselect", "tidyselect", "vctrs",
#   . "vctrs", "vctrs", "vctrs", "rlang"), scope = c("::", NA, "local",
#   . NA, "::", "local", "local", "local", "local", "local", "local",
#   . "::", ":::", "local", "local", "::", "::", "local", "local",
#   . "local", "::", "::", ":::", "::", "::", NA, "::", "::", ":::",
#   . ":::", "::", ":::", ":::", ":::", "::", ":::", ":::", "::", "::",
#   . ":::", ":::", ":::", ":::", ":::", ":::", ":::", ":::", "::",
#   . "local", ":::", ":::", "::"), error_frame = c(FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, TRUE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE)), row.names = c(NA, -52L), version = 2L, class = c("rlang_trace",
#   . "rlib_trace", "tbl", "data.frame")), parent = NULL, i = "directsubsidy_partd",
#   .     subscript_type = "character", names = character(0), subscript_action = "subset",
#   .     subscript_arg = "directsubsidy_partd", rlang = list(inherit = TRUE),
#   .     call = across(), subscript_elt = "column"), class = c("vctrs_error_subscript_oob",
#   . "vctrs_error_subscript", "rlang_error", "error", "condition")))
# 36. abort(message, class = error_class, parent = parent, call = error_call)
# 37. signal_abort(cnd, .file)
